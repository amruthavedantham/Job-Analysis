# %% [markdown]
# # 📘 Job Analysis - Data Analysis Project
#
# ![Job Analysis](https://www.tytonmedia.com/wp-content/uploads/web-design-stats-2016.png)
#
#
# ## 🧭 Overview
# This project performs exploratory data analysis (EDA) on a job listings dataset to uncover valuable insights regarding the job market. It aims to understand hiring trends, top roles, skills in demand, and job distribution by location and company. The analysis is useful for job seekers, recruiters, and HR analysts aiming to stay informed on employment patterns.
#
# ---
#
# ## 🎯 Objective
# - To identify popular job titles and top hiring companies.
# - To analyze job distribution across locations.
# - To examine required skills and hiring patterns.
# - To clean and visualize the dataset effectively for actionable insights.
#
# ---
#
# ## 📊 Sample Data
# Here is a preview of 5 random rows from the dataset to understand its structure:
#
# | job_id          | job_role                                     | company                                      | experience | salary                     | location                            | rating | reviews        | resposibilities                                                         |
# |------------------|---------------------------------------------|---------------------------------------------|------------|----------------------------|-------------------------------------|--------|----------------|------------------------------------------------------------------------|
# | 1.511226e+11    | Business Sales Manager - Banca | Life Insurance | Lavya Associates                            | 5-10 Yrs   | 6,00,000 - 8,00,000 PA.   | Jorhat                              | NaN    | NaN            | Life Insurance, BFSI, Bancassurance, team handling                      |
# | 3.012220e+11    | HR Manager 1                                 | Emerald Paper Products                       | 2-7 Yrs    | 1,75,000 - 2,50,000 PA.   | Hybrid - Mohanlalganj               | NaN    | NaN            | Human Resource Management, hr, monitoring, Recruitment                 |
# | 2.012350e+10    | Executive- DevOps Engineer                   | Rahi                                         | 3-8 Yrs    | Not disclosed             | Pune                                | NaN    | NaN            | Linux, Jenkins, web services, Gitlab, Puppet, DevOps                   |
# | 5.012300e+10    | Operation Executive (Females Only)           | Eduworld Bangalore Educational Services      | 1-6 Yrs    | 1,25,000 - 2,50,000 PA.   | Trivandrum/Thiruvananthapuram       | NaN    | NaN            | Team Management, Team Handling, Team Leading, Brand Development        |
# | 7.012350e+10    | Product Owner - Arcadis Gen                  | Arcadis Consulting India Pvt. Ltd            | 4-7 Yrs    | Not disclosed             | Noida, Mumbai                       | 4.2    | 145 Reviews    | Product management, Sales, SAP, Performance management                 |
#
# ---
#
# ## **Data Processing**
# - Handled null values and removed duplicates for integrity.
# - Cleaned and standardized salary and experience fields.
# - Dropped irrelevant columns to streamline analysis.
#
# ---
#
# ## 🔑 Key Insights
#
# - **Top Hiring Companies**: Companies like *IBM* and *Dell* have high hiring counts.
# - **Most Demanded Job Titles**: Roles like *Data Analyst*, *Software Engineer*, and *Data Scientist* frequently appeared.
# - **Location Trends**: Countries like *Egypt*, *UAE*, and *KSA* had the most job openings.
# - **Popular Skills**: Python, SQL, and Communication skills are highly sought after.
#
# ---
#
# ## 📈 Visualizations
#
# - **Bar Charts**: For top job titles and hiring companies.
# - **Pie Charts**: To show job type and level distributions.
# - **Countplots & Word Clouds**: To visualize skill frequencies and title distributions.
# - **Seaborn & Matplotlib**: Used for styling and detailed visual representations.
#
# ---
#
# ## 🧰 Technologies Used
#
# - **Google Colab**: Execution environment.
# - **Python**: Main programming language.
# - **Libraries**:
#   - `Pandas` – Data manipulation
#   - `Matplotlib` & `Seaborn` – Visualization
#   - `NumPy` – Numerical operations
#
# ---
#
# ## 🚀 Future Enhancements
#
# - Add time-series trends if date data is available.
# - Perform NLP on job descriptions for deeper insights.
# - Develop an interactive dashboard using Plotly, Dash, or Streamlit.
# - Predict job demand using machine learning models.
#
# ---
#
# ## 👩‍💻 Author
# **Name**: [V Amrutha Varshini]  - [GitHub Profile](https://github.com/amruthavedantham)
#
# ---
#
# ## 📄 License
#
# This project is licensed under the **Creative Commons CC BY 4.0 License**.

# %% [markdown]
# ##0. LOADING THE DATA
#
# ####The dataset used for this project was loaded from a CSV file using the `pandas` library. It contains structured information about various job listings, including job title, company name, location, type, level, years of experience, country, and skills required.

# %%
# !git clone https://github.com/AshishJangra27/datasets
# Out:
# fatal: destination path 'datasets' already exists and is not an empty directory.

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

df = pd.read_csv('/content/datasets/Job Postings/jobs.csv.zip')

# %% [markdown]
# ## 1. Data Exploration
#
# ####The data exploration phase involves understanding the basic structure and summary of the dataset. This step provides an overview of the available features, data types, and the general quality of the data. <br>
# ####During this phase, column names were examined, data types were inspected, and statistical summaries were generated. <br>
# ####This helped in identifying anomalies, inconsistencies, or potential data quality issues that needed to be addressed before further analysis.

# %%
df.head()
# Out:
#          job_id                                           job_role    company  \
# 0  7.012301e+10      Branch Banking - Calling For Women Candidates  Hdfc Bank
# 1  6.012391e+10                       Product Owner Senior Manager  Accenture
# 2  6.012391e+10  Employee Relations and Policies Associate Manager  Accenture
# 3  6.012391e+10         Employee Relations and Policies Specialist  Accenture
# 4  6.012301e+10                                  SAP BO Consultant   Mindtree
#
#   experience         salary  \
# 0    1-6 Yrs  Not disclosed
# 1  11-15 Yrs  Not disclosed
# 2    3-7 Yrs  Not disclosed
# 3    3-7 Yrs  Not disclosed
# 4    5-7 Yrs  Not disclosed
#
#                                             location  rating        reviews  \
# 0  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...     4.0  39110 Reviews
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
# 2  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79147 entries, 0 to 79146
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_id           78667 non-null  float64
#  1   job_role         78667 non-null  object
#  2   company          78666 non-null  object
#  3   experience       77398 non-null  object
#  4   salary           78667 non-null  object
#  5   location         77441 non-null  object
#  6   rating           42948 non-null  float64
#  7   reviews          42948 non-null  object
#  8   resposibilities  78647 non-null  object
#  9   posted_on        78667 non-null  object
#  10  job_link         78667 non-null  object
#  11  company_link     78667 non-null  object
# dtypes: float64(2), object(10)
# memory usage: 7.2+ MB

# %% [markdown]
# ### Checking Null Values
#
# Handling missing data is a critical step in ensuring the reliability of the analysis. The dataset was examined for null or missing values in each column. Key columns such as `Years of Experience`, `Level`, and `Skills` had missing entries. These gaps can impact both visualization and decision-making, so strategies such as data imputation or row removal were considered depending on the nature and significance of the missing values.

# %%
df.isnull().sum()
# Out:
# job_id               480
# job_role             480
# company              481
# experience          1749
# salary               480
# location            1706
# rating             36199
# reviews            36199
# resposibilities      500
# posted_on            480
# job_link             480
# company_link         480
# dtype: int64

# %% [markdown]
# ### Checking Duplicates
#
# Duplicate records, if present, can misrepresent trends and skew results. As part of the cleaning process, the dataset was scanned for exact duplicate rows. Any redundant records found were removed to maintain the uniqueness and accuracy of the data. This ensures that each data point contributes equally to the insights drawn.

# %%
df.duplicated(subset = 'job_id').sum()
# Out:
# np.int64(6137)

# %% [markdown]
# ### Removing Unwanted Columns
# Some columns in the dataset did not add value to the analysis. For instance, index columns or columns generated during data export (like unnamed indices) were identified as irrelevant. These were dropped to simplify the dataset and reduce noise. Streamlining the dataset allows for clearer visualizations and more focused insights.

# %%
del df['posted_on']
del df['company_link']
del df['job_link']

# %%
df.head()
# Out:
#          job_id                                           job_role    company  \
# 0  7.012301e+10      Branch Banking - Calling For Women Candidates  Hdfc Bank
# 1  6.012391e+10                       Product Owner Senior Manager  Accenture
# 2  6.012391e+10  Employee Relations and Policies Associate Manager  Accenture
# 3  6.012391e+10         Employee Relations and Policies Specialist  Accenture
# 4  6.012301e+10                                  SAP BO Consultant   Mindtree
#
#   experience         salary  \
# 0    1-6 Yrs  Not disclosed
# 1  11-15 Yrs  Not disclosed
# 2    3-7 Yrs  Not disclosed
# 3    3-7 Yrs  Not disclosed
# 4    5-7 Yrs  Not disclosed
#
#                                             location  rating        reviews  \
# 0  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...     4.0  39110 Reviews
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
# 2  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
# ...

# %% [markdown]
# ## 2. Data Cleaning
#
# ---
#
# ####This phase focused on preparing the dataset for meaningful analysis by handling inconsistencies, missing values, incorrect types, and formatting issues.

# %% [markdown]
# ### Dealing with Null Values (except for reviews and ratings)
# Missing values were identified and removed from all columns except for `Reviews` and `Ratings`, which were retained for their optional nature in job listings.

# %%
df['location'].value_counts()
# Out:
# location
# Bangalore/Bengaluru                                                                          10035
# Hyderabad/Secunderabad                                                                        3736
# Pune                                                                                          3216
# Chennai                                                                                       2953
# Mumbai                                                                                        2818
#                                                                                              ...
# Panvel, Andheri, Nerul                                                                           1
# Surendranagar, Mehsana, Gandhinagar, Sanand, Ahmedabad, Rajkot                                   1
# Kalol, Mahesana, Surendranagar, Mundra, Morvi, Gandhinagar, Patan, Deesa, Ahmedabad              1
# ...

# %%
df = df.dropna(subset = ['job_id','resposibilities','company'])
df['experience'] = df['experience'].fillna('5-10 Yrs')
df['location'] = df['location'].fillna('Bangalore/Bengaluru')
df['rating'] = df['rating'].fillna('0.0')
df['reviews'] = df['reviews'].fillna('0 Reviews')

# %%
df.isnull().sum()
# Out:
# job_id             0
# job_role           0
# company            0
# experience         0
# salary             0
# location           0
# rating             0
# reviews            0
# resposibilities    0
# dtype: int64

# %% [markdown]
# ### Dealing with Duplicates
#
# Duplicate rows were removed to avoid repetition and ensure that each job listing contributed uniquely to the analysis.

# %%
df = df.drop_duplicates(subset = 'job_id')

# %% [markdown]
# ### Changing DataType
# Data types were standardized where necessary, such as converting numerical or object columns into appropriate formats for analysis.

# %%
type(df['job_id'][0])
# Out:
# numpy.float64

# %%
df['job_id'] = df['job_id'].astype('str')

# %%
type(df['job_id'][0])
# Out:
# str

# %% [markdown]
# ### Cleaning Experience Column
#
# Text-based experience values were cleaned to retain only numerical ranges, removing characters like '+' and converting strings to integers for easier comparison.

# %%
df['min_experience'] = df['experience'].str.replace('Yrs','').str.split('-').str[0].str.strip().astype('int')
df['max_experience'] = df['experience'].str.replace('Yrs','').str.split('-').str[1].str.strip().astype('int')
del df['experience']

# %%
df.head()
# Out:
#           job_id                                           job_role  \
# 0  70123006070.0      Branch Banking - Calling For Women Candidates
# 1  60123905908.0                       Product Owner Senior Manager
# 2  60123905898.0  Employee Relations and Policies Associate Manager
# 3  60123905897.0         Employee Relations and Policies Specialist
# 4  60123008332.0                                  SAP BO Consultant
#
#      company         salary  \
# 0  Hdfc Bank  Not disclosed
# 1  Accenture  Not disclosed
# 2  Accenture  Not disclosed
# 3  Accenture  Not disclosed
# 4   Mindtree  Not disclosed
#
#                                             location rating        reviews  \
# 0  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...    4.0  39110 Reviews
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...    4.1  32129 Reviews
# 2  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...    4.1  32129 Reviews
# 3  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...    4.1  32129 Reviews
# ...

# %% [markdown]
# ### Cleaning Salary Column
#
# Salary data was stripped of currency symbols, punctuation, and text, and then transformed into a consistent numeric format suitable for analysis.

# %%
import numpy as np

df['salary'] = df['salary'].replace('Not disclosed', np.nan)

# %%
df['salary']
# Out:
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#                   ...
# 73762    7,00,000 - 8,50,000 PA.
# 73763    7,00,000 - 8,50,000 PA.
# 73764    3,00,000 - 4,50,000 PA.
# 73765                        NaN
# 73766                        NaN
# Name: salary, Length: 72988, dtype: object

# %%
import numpy as np

def extract_salary_range(s):
    if pd.isna(s) or 'Not disclosed' in str(s):
        return (np.nan, np.nan)

    s = s.replace('₹', '').replace(',', '').lower().strip()

    # Handle "less than" type
    if 'less than' in s:
        number = ''.join(c for c in s if c.isdigit() or c == '.')
        if number:
            return (0.0, float(number))
        else:
            return (np.nan, np.nan)

    # Handle "X - Y Lakhs" or "X - Y" formats
    if '-' in s:
        parts = s.split('-')
        try:
            min_sal = float(parts[0].strip().split()[0])
            max_sal = float(parts[1].strip().split()[0])
            return (min_sal, max_sal)
        except:
            return (np.nan, np.nan)

    # Handle single value
    try:
        value = float(s.strip().split()[0])
        return (value, value)
    except:
        return (np.nan, np.nan)

# Apply safely
df[['min_salary', 'max_salary']] = df['salary'].apply(extract_salary_range).apply(pd.Series)

# Optional: average salary
df['avg_salary'] = df[['min_salary', 'max_salary']].mean(axis=1)

# %%
df.tail()
# Out:
#                job_id                                           job_role  \
# 73762   20123002989.0            Partner Success Executive/Edtech/Punjab
# 73763   20123002957.0            Partner Success Associate/Edtech/Punjab
# 73764  231222003986.0  Hiring For International Voice Process | Gurga...
# 73765  171220001449.0                                   Fresher Engineer
# 73766   71022008732.0            Anatomy Trainer - Part Time / Full time
#
#                      company                   salary  \
# 73762       Parth Associates  7,00,000 - 8,50,000 PA.
# 73763       Parth Associates  7,00,000 - 8,50,000 PA.
# 73764   First Step Solutions  3,00,000 - 4,50,000 PA.
# 73765                 Sofcon                      NaN
# 73766  Indian Healthcare BPO                      NaN
#
#                                                 location rating    reviews  \
# 73762                    Jalandhar, Chandigarh, Amritsar    0.0  0 Reviews
# ...

# %% [markdown]
# ### Cleaning Review Column
# Non-numeric characters and text were removed from the `Reviews` column to keep only valid review counts; missing values were filled with zero.

# %%
df['reviews'] = df['reviews'].str.split(' ').str[0].astype('int')

# %%
df['reviews']
# Out:
# 0        39110
# 1        32129
# 2        32129
# 3        32129
# 4         3759
#          ...
# 73762        0
# 73763        0
# 73764        0
# 73765        3
# 73766        0
# Name: reviews, Length: 72988, dtype: int64

# %% [markdown]
# ## 3. Data Analysis and Visualization
#
# ---
#
# ####This stage involves deriving meaningful insights from the cleaned dataset through analytical queries and visual representations using charts and graphs.

# %% [markdown]
# ### Overall Analysis
# General insights such as job distribution by country, job levels, and company types were observed to understand the broader job market landscape.

# %%
print('-'*30)
print('Total Jobs         : ', len(df))
print('Total Companies    : ', df['company'].nunique())
print('-'*30)
# Out:
# ------------------------------
# Total Jobs         :  72988
# Total Companies    :  15313
# ------------------------------

# %% [markdown]
# ###Top 5 Companies
# The top five companies with the highest number of job postings were identified, revealing major recruiters and market leaders.

# %% [markdown]
# #### Based on Reviews

# %%
df.groupby('company')['reviews'].count().sort_values(ascending = False).head()
# Out:
# company
# Lavya Associates          5128
# Accenture                 2928
# Hucon                      852
# Varite India Pvt. Ltd.     815
# IBM                        656
# Name: reviews, dtype: int64

# %%
import plotly.express as px
top_reviews = df.groupby('company')['reviews'].count().sort_values(ascending=False).head().reset_index()
top_reviews.columns = ['company', 'review_count']

fig = px.pie(
    top_reviews,
    names='company',
    values='review_count',
    title='Top 5 Companies by Number of Reviews',
    color_discrete_sequence=px.colors.sequential.Purples
)
fig.update_layout(
    paper_bgcolor='#aeb1b5',
    plot_bgcolor='#aeb1b5',
    font_color='black',
    title_font_color='black'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Based on JobID

# %%
df.groupby('company')['job_id'].count().sort_values(ascending = False).head()
# Out:
# company
# Lavya Associates          5128
# Accenture                 2928
# Hucon                      852
# Varite India Pvt. Ltd.     815
# IBM                        656
# Name: job_id, dtype: int64

# %% [markdown]
# #### Based on Rating

# %%
df.groupby('company')['rating'].count().sort_values(ascending = False).head()
# Out:
# company
# Lavya Associates          5128
# Accenture                 2928
# Hucon                      852
# Varite India Pvt. Ltd.     815
# IBM                        656
# Name: rating, dtype: int64

# %% [markdown]
# #### Based on Maximum Salary

# %%
df.groupby('company')['max_salary'].count().sort_values(ascending = False).head()
# Out:
# company
# Lavya Associates               5128
# Jobshop Consulting              237
# Outpace Consulting Services     170
# Adecco Group                    160
# Tech Mahindra                   154
# Name: max_salary, dtype: int64

# %% [markdown]
# #### **Top 10 Companies by Minimum Reviews**

# %%
df.groupby('company')['reviews'].min().sort_values(ascending=False).head(10)
# Out:
# company
# Tata Consultancy Services (TCS)             50163
# Reliance Industries (RIL)                   43672
# Hdfc Bank                                   39110
# Icici Bank                                  33480
# Accenture                                   32129
# Larsen & Toubro (L&T)                       24041
# L&T Infrastructure Engineering Limited      24041
# L & T Infrastructure Engineering Limited    24041
# L&T Technology Services                     24022
# Capgemini                                   23786
# Name: reviews, dtype: int64

# %%
import pandas as pd
import plotly.express as px

company_reviews = df.groupby('company')['reviews'].min().sort_values(ascending=False).head(10)

company_reviews = company_reviews.reset_index()

fig = px.pie(
    company_reviews,
    names='company',
    values='reviews',
    title='Top 10 Companies by Minimum Reviews (Descending)',
    color_discrete_sequence=px.colors.sequential.Blues
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Companies Hiring Data Analyst
#
# A focused analysis filtered job listings with the title “Data Analyst” to find which companies are actively hiring for this specific role.

# %%
data_analyst_companies = df[df['job_role'] == 'Data Analyst']['company'].unique()

print(f"Total companies hiring Data Analysts: {len(data_analyst_companies)}")
print(data_analyst_companies)
# Out:
# Total companies hiring Data Analysts: 53
# ['Publicis Groupe' 'Omniactive Health Technologies' 'Quickxpert Infotech'
#  'GlobalLogic' 'Target' 'Hackerearth' 'Cointab Software'
#  'Control Risks India Pvt Ltd.' 'Axis My India Ltd.' 'Instinox Llp'
#  'Goldenpi Technologies' 'Kaleidofin' 'Dronebase' 'LKQ India'
#  'Nichepro Technologies Pvt.ltd.' 'Onit' 'CliqHR Recruitment Services'
#  'Quess It Staffing' 'Ergode It Services' 'Shell' 'Maruti Suzuki'
#  'Arcadia' 'S&P Global Inc.' 'PubMatic' 'Radical Technologies'
#  '24dimensions' 'Vashi Integrated Solutions' 'Pragmath'
#  'Redwind Technology' 'Futures First' 'Webhelp India'
#  'Feathersoft Info Solutions' 'Lemniscate Technologies' 'Webhelp'
#  'Bluebox Infosoft' 'Transunion' 'Forwood Safety'
#  'Rewise Analytics & Technologies' 'Varite India Pvt. Ltd.'
#  'NatWest Markets' 'Smartanalyst India Pvt Ltd' 'RAVR INDUSTRIES PVT LTD'
#  'Prohub Technologies' 'Megma Services' 'Thirstycrew Solutions'
# ...

# %%
analyst_jobs = df[df['job_role'].str.contains('data analyst', case=False, na=False)]
analyst_companies_df = analyst_jobs[['company']].drop_duplicates()
print(analyst_companies_df)
# Out:
#                              company
# 78                   Publicis Groupe
# 173                    Tech Mahindra
# 263                            Croma
# 844                           Jacobs
# 1973                        Flipkart
# ...                              ...
# 66629                People Staffing
# 67446                 NMS Consultant
# 70622              Venus Consultancy
# 70833          Corporate Destination
# 71985  GenNext India Private Limited
#
# [137 rows x 1 columns]

# %%
analyst_jobs = df[df['job_role'].str.contains('data analyst', case=False, na=False)]
company_counts = analyst_jobs['company'].value_counts().head(10)

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.barplot(x=company_counts.values, y=company_counts.index, palette='flare')
plt.title('Top 10 Companies Hiring Data Analysts')
plt.xlabel('Number of Job Postings')
plt.ylabel('Company')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Skills needed for almost all jobs
#
# Frequently occurring skills across all job listings were extracted using keyword analysis, indicating core skills consistently in demand.

# %%
df['resposibilities'].str.lower().str.split(',').explode().value_counts().head(10)
# Out:
# resposibilities
# sales               6159
# communication       4010
# customer service    3803
# agency              3457
# tied                3313
# java                3297
# training            3188
# consulting          2929
# javascript          2890
# team handling       2632
# Name: count, dtype: int64

# %%
import plotly.express as px

top_responsibilities = (
    df['resposibilities']
    .str.lower()
    .str.split(',')
    .explode()
    .str.strip()
    .value_counts()
    .head(10)
    .reset_index()
)
top_responsibilities.columns = ['responsibility', 'count']

fig = px.bar(
    top_responsibilities,
    x='count',
    y='responsibility',
    orientation='h',
    title='Top 10 Job Responsibilities',
    color='responsibility',
    color_discrete_sequence=px.colors.qualitative.Pastel
)

fig.update_layout(
    paper_bgcolor='#f0f0f0',
    plot_bgcolor='#f0f0f0',
    font_color='black',
    title_font_size=20,
    yaxis=dict(categoryorder='total ascending')
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Skills to get hired for in HDFC Bank
#
# Jobs listed under HDFC Bank were analyzed to determine the most common skills required, helping tailor applications for this company.

# %%
hdfc_jobs = df[df['company'].str.contains('Hdfc Bank', case=False, na=False)]

hdfc_skills = (
    hdfc_jobs['resposibilities']
    .dropna()
    .str.lower()
    .str.split(',')
    .explode()
    .str.strip()
    .value_counts()
    .head(10)
    .reset_index()
)
hdfc_skills.columns = ['skill', 'count']

fig = px.bar(
    hdfc_skills,
    x='skill',
    y='count',
    title='Top 10 Skills Required at HDFC Bank',
    color='count',
    color_continuous_scale=px.colors.sequential.Greens
)

fig.update_layout(
    paper_bgcolor='#abc2c4',
    plot_bgcolor='#abc2c4',
    font_color='black',
    title_font_size=20
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Skills needed to become a Data Analyst
#
# A breakdown of skill requirements specific to the “Data Analyst” role highlighted essential technical and analytical competencies.

# %%
analyst_jobs = df[df['job_role'].str.contains('data analyst', case=False, na=False)]
analyst_skills = (
    analyst_jobs['resposibilities']
    .dropna()
    .str.lower()
    .str.split(',')
    .explode()
    .str.strip()
    .value_counts()
    .head(10)
    .reset_index()
)
analyst_skills.columns = ['skill', 'count']
fig = px.bar(
    analyst_skills,
    x='count',
    y='skill',
    orientation='h',
    title='Top 10 Skills Required for Data Analyst Roles',
    color='skill',
    color_discrete_sequence=px.colors.sequential.Sunset
)

fig.update_layout(
    paper_bgcolor='#f5f5f5',
    plot_bgcolor='#f5f5f5',
    font_color='black',
    title_font_size=20,
    yaxis=dict(categoryorder='total ascending')
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### No. of Jobs as per the years of experience
#
# Jobs were grouped by required experience levels to visualize the availability of roles across various experience brackets, aiding entry-level and senior applicants.

# %%
df['min_experience'].value_counts()
# Out:
# min_experience
# 5     12090
# 1     10955
# 2     10594
# 3      9695
# 0      9645
# 4      7943
# 6      2975
# 8      2566
# 10     2261
# 7      2102
# 12      670
# 15      498
# 9       460
# 11      123
# 14      113
# 13       69
# 20       68
# 18       56
# 16       36
# 17       17
# 25       13
# 21       11
# 19       10
# 22        4
# 26        4
# 24        3
# 28        3
# 23        3
# 27        1
# Name: count, dtype: int64

# %%
import plotly.express as px

experience_counts = df['min_experience'].value_counts().reset_index()
experience_counts.columns = ['min_experience', 'number_of_jobs']

fig = px.bar(experience_counts,
             x='min_experience',  # Use 'min_experience' here
             y='number_of_jobs',
             title='Number of Jobs by Minimum Experience',
             labels={'min_experience': 'Minimum Experience (Years)', 'number_of_jobs': 'Number of Jobs'},
             color='min_experience')

fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Average Salary for Specific years of Experience
#
# The average salary for each experience level was calculated to understand compensation trends and how experience influences pay.

# %%
average_salary_by_experience = df.groupby('min_experience')['avg_salary'].mean().reset_index()
print(average_salary_by_experience)
# Out:
#     min_experience    avg_salary
# 0                0  4.412528e+06
# 1                1  4.200954e+05
# 2                2  6.083603e+05
# 3                3  7.611331e+05
# 4                4  9.108752e+05
# 5                5  8.688609e+05
# 6                6  1.476184e+06
# 7                7  1.903618e+06
# 8                8  1.625142e+06
# 9                9  1.720565e+06
# 10              10  1.723566e+06
# 11              11  1.946382e+06
# 12              12  2.079885e+06
# 13              13  2.806522e+06
# 14              14  2.633784e+06
# 15              15  2.651033e+06
# 16              16  2.337917e+06
# 17              17  4.200000e+06
# 18              18  2.386842e+06
# 19              19  1.320833e+06
# 20              20  3.071970e+06
# 21              21  3.951389e+06
# 22              22  5.075000e+06
# 23              23  4.125000e+06
# 24              24  9.250000e+05
# 25              25  4.504688e+06
# 26              26  1.162500e+06
# ...

# %%
import plotly.express as px

average_salary_by_experience = df.groupby('min_experience')['avg_salary'].mean().reset_index()

fig = px.bar(average_salary_by_experience,
             x='min_experience',
             y='avg_salary',
             title='Average Salary by Minimum Experience',
             labels={'min_experience': 'Minimum Experience (Years)', 'avg_salary': 'Average Salary'})

fig.update_layout(xaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## ✨ Final Conclusion and Insights ✨
#
# ---
# <br>
#
# Based on the comprehensive data analysis and visualization performed in this project, the following key insights and conclusions were derived:
#
# ### 1. Job Market Landscape
#
# - **Total Jobs and Companies:**
#   The dataset comprises a substantial number of job postings from a diverse range of companies, indicating a healthy and active job market.
#
# - **Company Hiring Activity:**
#   By analyzing job counts per company (based on `job_id`), we identified the top hiring companies, revealing the major players in the job market. Companies like IBM, Dell, and others had high hiring volumes.
#
# ### 2. Demanded Roles and Skills
#
# - **Most Frequent Job Titles:**
#   Analyzing the frequency of `job_role` revealed the most sought-after job titles. Roles such as Data Analyst, Software Engineer, and Data Scientist were consistently among the top, reflecting the strong demand in the tech and data sectors.
#
# - **Universally Needed Skills:**
#   Examination of the `responsibilities` column, after cleaning and tokenization, highlighted skills that appear across a broad spectrum of job postings. These are fundamental skills highly valued by employers regardless of the specific role.
#
# - **Role-Specific Skills:**
#   By filtering job roles (e.g., 'Data Analyst'), we were able to identify the specific technical and soft skills most frequently listed for those positions, providing clear guidance for individuals targeting those roles.
#
# ### 3. Company-Specific Hiring Trends
#
# - **Top Companies by Various Metrics:**
#   We explored the top companies based on different metrics like the count of reviews, job postings, ratings, and maximum salary. This provided a multi-faceted view of which companies are prominent and potentially more attractive based on these factors.
#
# - **Skills in Specific Companies:**
#   Focusing on specific companies (e.g., HDFC Bank), we extracted the most required skills for their listed jobs. This targeted analysis is highly valuable for job seekers interested in particular employers.
#
# ### 4. Experience and Salary Analysis
#
# - **Jobs by Experience Level:**
#   Analyzing the distribution of job postings based on the minimum required `experience` (after cleaning and converting to numerical ranges) showed the availability of roles across different career stages. This helps understand the demand for entry-level vs. experienced professionals.
#
# - **Salary Trends by Experience:**
#   Calculating the average salary for different minimum experience levels provided insights into how compensation scales with experience. This is a crucial data point for understanding salary expectations and negotiating offers.
#
# ### 5. Data Quality and Preparation
#
# - **Importance of Cleaning:**
#   The initial exploration revealed null values and duplicates, emphasizing the critical need for data cleaning. Handling these issues (filling nulls, removing duplicates, standardizing data types) ensured the reliability of the subsequent analysis.
#
# - **Feature Engineering:**
#   Cleaning and transforming columns like `experience` and `salary` into numerical formats (`min_experience`, `max_experience`, `avg_salary`) was essential for quantitative analysis and visualization.
#
# ### 6. Visualization Impact
#
# - **Visual Clarity:**
#   The use of various visualizations (bar charts, pie charts) from `matplotlib`, `seaborn`, and `plotly.express` effectively communicated the key findings. For example, bar charts clearly showed the distribution of jobs by experience, while pie charts illustrated the proportion of reviews per company. The interactive nature of Plotly plots enhanced the ability to explore the data.
